# %%
# Symbolic computation tools
import sympy as sp
from sympy import symbols, pprint, Function, simplify, Derivative, nsimplify
from sympy import sin, cos, 
from sympy import Matrix, latex, BlockMatrix, lambdify
import numpy as np

import matplotlib.pyplot as ptl
from scipy.integrate import solve_ivp
from sympy import init_printing
init_printing()

# %% [markdown]
# Tutorial 1 - Introduction to jupyter lab and python

# %%
whos
# Out:
# Variable        Type              Data/Info
# -------------------------------------------
# BlockMatrix     type              <class 'sympy.matrices.ex<...>blockmatrix.BlockMatrix'>
# Derivative      type              <class 'sympy.core.function.Derivative'>
# Function        FunctionClass     Function
# Matrix          type              <class 'sympy.matrices.dense.MutableDenseMatrix'>
# init_printing   function          <function init_printing at 0x000001BA244C9630>
# lambdify        function          <function lambdify at 0x000001BA223A3D90>
# latex           _PrintFunction    <sympy.printing.printer._<...>ct at 0x000001BA23B0DBA0>
# np              module            <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# nsimplify       function          <function nsimplify at 0x000001BA242C6200>
# pprint          function          <function pretty_print at 0x000001BA20A4B640>
# ptl             module            <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# ...

# %% [markdown]
# I like to have a console open as I am working in notebooks. So I can quick queries and rapidly debug stuff

# %%
# %qtconsole

# %%
vec = np.matrix([[1],[2]])

# %%
ll = np.zeros([100,1])
for kk in range(100)
    ll.append(kk*2)
vec_list = np.array(ll)
# Out:
#   Cell In[11], line 2
#     for kk in range(100)
#                         ^
# SyntaxError: expected ':'

# %%
t = sp.symbols('t', real=True)

# %%
alpha = Function('theta', real=True)(t)

# %%
def pendejo(x,y,theta)
    return sp.matrix(cos(theta), sin(theta), x, y)
# Out:
#   Cell In[17], line 1
#     def pendejo(x,y,theta)
#                           ^
# SyntaxError: expected ':'

# %%
pendejo(1,2,4)
